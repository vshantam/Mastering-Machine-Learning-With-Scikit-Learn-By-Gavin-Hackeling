# %% [markdown]
# <H3> Excercise 1: Spam Filtering </H3>

# %% [markdown]
# <H2> Logistic Regression</H2>

# %%
# Importing the data

import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model.logistic import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score

# %%
#Checking files in current directory
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'smsspamcollection', 'Untitled.ipynb']

# %%
# Creating Dataframe
df = pd.read_csv('smsspamcollection/SMSSpamCollection', delimiter = '\t', header = None)
df.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#slitting data set  into training and testing set
x_train, x_test, y_train, y_test = train_test_split(df[1], df[0])

# %%
# Creating TFIDF Vectorizer
vectorizer = TfidfVectorizer()

#Transforming Training set
x_train_f = vectorizer.fit_transform(x_train)
x_test_f = vectorizer.transform(x_test)
# Out:
# <1x7564 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
# Visualizing the values 
print(x_train[0])
print(x_train_f[0])
print(y_train[0])
# Out:
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
#   (0, 6194)	0.6377124031463361
#   (0, 980)	0.6107648861049088
#   (0, 6657)	0.46934970413816457
# ham

# %%
# Creating and Fitting the model
clf = LogisticRegression()
clf.fit(x_train_f,y_train)
# Out:
# LogisticRegression()

# %%
#pridicting the model
for i in range(len(x_test)):
    #print(x_test.iloc[i], clf.predict(x_test_f[i]))
    print("S.No. "+str(i) + ": Message : {0} -- Prediction : {1}\n".format(x_test.iloc[i], clf.predict(x_test_f[i])))
# Out:
# S.No. 0: Message : Are you still playing with gautham? -- Prediction : ['ham']
#
# S.No. 1: Message : Yeah like if it goes like it did with my friends imma flip my shit in like half an hour -- Prediction : ['ham']
#
# S.No. 2: Message : Bears Pic Nick, and Tom, Pete and ... Dick. In fact, all types try gay chat with photo upload call 08718730666 (10p/min). 2 stop texts call 08712460324 -- Prediction : ['spam']
#
# S.No. 3: Message : Howz that persons story -- Prediction : ['ham']
#
# S.No. 4: Message : YOUR CHANCE TO BE ON A REALITY FANTASY SHOW call now = 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national = rate call. -- Prediction : ['spam']
#
# S.No. 5: Message : Staff of placement training in Amrita college. -- Prediction : ['ham']
#
# S.No. 6: Message : Well the weather in cali's great. But its complexities are great. You need a car to move freely, its taxes are outrageous. But all in all its a great place. The sad part is i missing home. -- Prediction : ['ham']
#
# S.No. 7: Message : And you! Will expect you whenever you text! Hope all goes well tomo  -- Prediction : ['ham']
#
# S.No. 8: Message : How do you plan to manage that -- Prediction : ['ham']
#
# S.No. 9: Message : Okie.. Thanx.. -- Prediction : ['ham']
#
# S.No. 10: Message : Siva is in hostel aha:-. -- Prediction : ['ham']
#
# S.No. 11: Message : Pls send me the correct name da. -- Prediction : ['ham']
#
# S.No. 12: Message : Yo carlos, a few friends are already asking me about you, you working at all this weekend? -- Prediction : ['ham']
#
# S.No. 13: Message : i want to grasp your pretty booty :) -- Prediction : ['ham']
#
# S.No. 14: Message : Isn't frnd a necesity in life? imagine urself witout a frnd.. hw'd u feel at ur colleg? wat'll u do wth ur cell? wat abt functions? thnk abt events espe'll cared, missed &amp; irritated u? 4wrd it to all those dear-loving frnds wthout whom u cant live.. I jst did it.. Takecare..:) GOODMORNING -- Prediction : ['ham']
#
# S.No. 15: Message : I think it's all still in my car -- Prediction : ['ham']
#
# S.No. 16: Message : Hahaha..use your brain dear -- Prediction : ['ham']
#
# S.No. 17: Message : Just gettin a bit arty with my collages at the mo, well tryin 2 ne way! Got a roast in a min lovely i shall enjoy that! -- Prediction : ['ham']
#
# S.No. 18: Message : As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there. -- Prediction : ['ham']
#
# S.No. 19: Message : Thts wat Wright Brother did to fly.. -- Prediction : ['ham']
#
# S.No. 20: Message : That's the trouble with classes that go well - you're due a dodgey one … Expecting mine tomo! See you for recovery, same time, same place  -- Prediction : ['ham']
#
# S.No. 21: Message : Ya, told..she was asking wats matter? -- Prediction : ['ham']
#
# S.No. 22: Message : May i call You later Pls -- Prediction : ['ham']
#
# S.No. 23: Message : Forgot it takes me 3 years to shower, sorry. Where you at/your phone dead yet? -- Prediction : ['ham']
#
# S.No. 24: Message : Your brother is a genius -- Prediction : ['ham']
#
# S.No. 25: Message : Shb b ok lor... Thanx... -- Prediction : ['ham']
#
# S.No. 26: Message : We have new local dates in your area - Lots of new people registered in YOUR AREA. Reply DATE to start now! 18 only www.flirtparty.us REPLYS150 -- Prediction : ['spam']
#
# S.No. 27: Message : Eerie Nokia tones 4u, rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles: GHOST, ADDAMSFA, MUNSTERS, EXORCIST, TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p -- Prediction : ['spam']
#
# S.No. 28: Message : Yep, at derek's house now, see you Sunday &lt;3 -- Prediction : ['ham']
#
# S.No. 29: Message : Congratulations YOU'VE Won. You're a Winner in our August £1000 Prize Draw. Call 09066660100 NOW. Prize Code 2309. -- Prediction : ['spam']
#
# S.No. 30: Message : Please CALL 08712402578 immediately as there is an urgent message waiting for you -- Prediction : ['spam']
#
# S.No. 31: Message : YES! The only place in town to meet exciting adult singles is now in the UK. Txt CHAT to 86688 now! 150p/Msg. -- Prediction : ['spam']
#
# S.No. 32: Message : K..k..i'm also fine:)when will you complete the course? -- Prediction : ['ham']
#
# S.No. 33: Message :  &lt;#&gt;  mins but i had to stop somewhere first. -- Prediction : ['ham']
#
# S.No. 34: Message : Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 -- Prediction : ['spam']
#
# S.No. 35: Message : FreeMsg: Hey - I'm Buffy. 25 and love to satisfy men. Home alone feeling randy. Reply 2 C my PIX! QlynnBV Help08700621170150p a msg Send stop to stop txts -- Prediction : ['ham']
#
# S.No. 36: Message : Tell where you reached -- Prediction : ['ham']
#
# S.No. 37: Message : Hmmm ... I thought we said 2 hours slave, not 3 ... You are late ... How should I punish you ? -- Prediction : ['ham']
#
# S.No. 38: Message : I had askd u a question some hours before. Its answer -- Prediction : ['ham']
#
# S.No. 39: Message : What time you thinkin of goin? -- Prediction : ['ham']
#
# S.No. 40: Message : Ok lor... -- Prediction : ['ham']
#
# S.No. 41: Message : FreeMsg>FAV XMAS TONES!Reply REAL -- Prediction : ['ham']
#
# S.No. 42: Message : Dude avatar 3d was imp. At one point i thought there were actually flies in the room and almost tried hittng one as a reflex -- Prediction : ['ham']
#
# S.No. 43: Message : Ü come lt 25 n pass to me lar -- Prediction : ['ham']
#
# S.No. 44: Message : Oh... Okie lor...We go on sat...  -- Prediction : ['ham']
#
# S.No. 45: Message : Okay, good, no problem, and thanx! -- Prediction : ['ham']
#
# S.No. 46: Message : Have you started in skye -- Prediction : ['ham']
#
# S.No. 47: Message : It's wylie, you in tampa or sarasota? -- Prediction : ['ham']
#
# S.No. 48: Message : it to 80488. Your 500 free text messages are valid until 31 December 2005. -- Prediction : ['spam']
#
# S.No. 49: Message : He dint tell anything. He is angry on me that why you told to abi. -- Prediction : ['ham']
#
# S.No. 50: Message : HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com -- Prediction : ['spam']
#
# S.No. 51: Message : Hi Dear Call me its urgnt. I don't know whats your problem. You don't want to work or if you have any other problem at least tell me. Wating for your reply. -- Prediction : ['ham']
#
# S.No. 52: Message : Had your mobile 10 mths? Update to the latest Camera/Video phones for FREE. KEEP UR SAME NUMBER, Get extra free mins/texts. Text YES for a call -- Prediction : ['spam']
#
# S.No. 53: Message : Thanx a lot 4 ur help! -- Prediction : ['ham']
#
# S.No. 54: Message : Do u still have plumbers tape and a wrench we could borrow? -- Prediction : ['ham']
#
# S.No. 55: Message : Somewhr someone is surely made 4 u. And God has decided a perfect time to make u meet dat person. . . . till den, . . . . . Enjoy ur crushes..!!!;-) -- Prediction : ['ham']
#
# S.No. 56: Message : Ok... -- Prediction : ['ham']
#
# S.No. 57: Message : They said if its gonna snow, it will start around 8 or 9 pm tonite! They are predicting an inch of accumulation. -- Prediction : ['ham']
#
# S.No. 58: Message : What * u wearing? -- Prediction : ['ham']
#
# S.No. 59: Message : So i could kiss and feel you next to me... -- Prediction : ['ham']
#
# S.No. 60: Message : We are both fine. Thanks -- Prediction : ['ham']
#
# S.No. 61: Message : For ur chance to win £250 cash every wk TXT: PLAY to 83370. T's&C's www.music-trivia.net custcare 08715705022, 1x150p/wk. -- Prediction : ['spam']
#
# S.No. 62: Message : See the forwarding message for proof -- Prediction : ['ham']
#
# S.No. 63: Message : Oh really?? Did you make it on air? What's your talent? -- Prediction : ['ham']
#
# S.No. 64: Message : Congrats! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16+ Close 300603 post BCM4284 Ldn WC1N3XX -- Prediction : ['spam']
#
# S.No. 65: Message : Just arrived, see you in a couple days &lt;3 -- Prediction : ['ham']
#
# S.No. 66: Message : Cool, want me to go to kappa or should I meet you outside mu -- Prediction : ['ham']
#
# S.No. 67: Message : IM GONNA MISS U SO MUCH -- Prediction : ['ham']
#
# S.No. 68: Message : HMM yeah if your not too grooved out! And im looking forward to my pound special :) -- Prediction : ['ham']
#
# S.No. 69: Message : Eatin my lunch... -- Prediction : ['ham']
#
# S.No. 70: Message : Today am going to college so am not able to atten the class. -- Prediction : ['ham']
#
# S.No. 71: Message : Ok lor. -- Prediction : ['ham']
#
# S.No. 72: Message : Cool. I am  &lt;#&gt;  inches long. hope you like them big! -- Prediction : ['ham']
#
# S.No. 73: Message : Its good to hear from you -- Prediction : ['ham']
#
# S.No. 74: Message : No 1 POLYPHONIC tone 4 ur mob every week! Just txt PT2 to 87575. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info -- Prediction : ['spam']
#
# S.No. 75: Message : Anything... -- Prediction : ['ham']
#
# S.No. 76: Message : This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate. -- Prediction : ['spam']
#
# S.No. 77: Message : Book which lesson? then you msg me... I will call up after work or sth... I'm going to get specs. My membership is PX3748 -- Prediction : ['ham']
#
# S.No. 78: Message : Are you at work right now ? -- Prediction : ['ham']
#
# S.No. 79: Message : Set a place for me in your heart and not in your mind, as the mind easily forgets but the heart will always remember. Wish you Happy Valentines Day! -- Prediction : ['ham']
#
# S.No. 80: Message : Ü still got lessons?  Ü in sch? -- Prediction : ['ham']
#
# S.No. 81: Message : Got fujitsu, ibm, hp, toshiba... Got a lot of model how to say... -- Prediction : ['ham']
#
# S.No. 82: Message : Yes..he is really great..bhaji told kallis best cricketer after sachin in world:).very tough to get out. -- Prediction : ['ham']
#
# S.No. 83: Message : Lol I know! They're so dramatic. Schools already closed for tomorrow. Apparently we can't drive in the inch of snow were supposed to get. -- Prediction : ['ham']
#
# S.No. 84: Message : Ok lor... Sony ericsson salesman... I ask shuhui then she say quite gd 2 use so i considering... -- Prediction : ['ham']
#
# S.No. 85: Message : Come to me right now, Ahmad -- Prediction : ['ham']
#
# S.No. 86: Message : Sounds gd... Haha... Can... Wah, u yan jiu so fast liao... -- Prediction : ['ham']
#
# S.No. 87: Message : How many licks does it take to get to the center of a tootsie pop? -- Prediction : ['ham']
#
# S.No. 88: Message : True lov n care wil nevr go unrecognized. though somone often makes mistakes when valuing it. but they will definitly undrstnd once when they start missing it. -- Prediction : ['ham']
#
# S.No. 89: Message : Sad story of a Man - Last week was my b'day. My Wife did'nt wish me. My Parents forgot n so did my Kids . I went to work. Even my Colleagues did not wish. -- Prediction : ['ham']
#
# S.No. 90: Message : East coast -- Prediction : ['ham']
#
# S.No. 91: Message : Why didn't u call on your lunch? -- Prediction : ['ham']
#
# S.No. 92: Message : Nah, Wednesday. When should I bring the mini cheetos bag over? -- Prediction : ['ham']
#
# S.No. 93: Message : K, fyi I'm back in my parents' place in south tampa so I might need to do the deal somewhere else -- Prediction : ['ham']
#
# S.No. 94: Message : I'm still looking for a car to buy. And have not gone 4the driving test yet. -- Prediction : ['ham']
#
# S.No. 95: Message : Nothing just getting msgs by dis name wit different no's.. -- Prediction : ['ham']
#
# S.No. 96: Message : PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires -- Prediction : ['spam']
#
# S.No. 97: Message : K.k:)when are you going? -- Prediction : ['ham']
#
# S.No. 98: Message : I think your mentor is , but not 100 percent sure. -- Prediction : ['ham']
#
# S.No. 99: Message : Thanks chikku..:-) gud nyt:-* -- Prediction : ['ham']
#
# S.No. 100: Message : Love it! Daddy will make you scream with pleasure! I am going to slap your ass with my dick! -- Prediction : ['ham']
#
# S.No. 101: Message : Jos ask if u wana meet up? -- Prediction : ['ham']
#
# S.No. 102: Message : We have to pick rayan macleran there. -- Prediction : ['ham']
#
# S.No. 103: Message : Someone has conacted our dating service and entered your phone because they fancy you!To find out who it is call from landline 09111030116. PoBox12n146tf15 -- Prediction : ['spam']
#
# S.No. 104: Message : Yun buying... But school got offer 2000 plus only... -- Prediction : ['ham']
#
# S.No. 105: Message : I.ll always be there, even if its just in spirit. I.ll get a bb soon. Just trying to be sure i need it. -- Prediction : ['ham']
#
# S.No. 106: Message : Ur balance is now £500. Ur next question is: Who sang 'Uptown Girl' in the 80's ? 2 answer txt ur ANSWER to 83600. Good luck! -- Prediction : ['spam']
#
# S.No. 107: Message : As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune -- Prediction : ['ham']
#
# S.No. 108: Message : Dis is yijue. I jus saw ur mail. In case huiming havent sent u my num. Dis is my num. -- Prediction : ['ham']
#
# S.No. 109: Message : HI HUN! IM NOT COMIN 2NITE-TELL EVERY1 IM SORRY 4 ME, HOPE U AVA GOODTIME!OLI RANG MELNITE IFINK IT MITE B SORTED,BUT IL EXPLAIN EVERYTHIN ON MON.L8RS.x -- Prediction : ['ham']
#
# S.No. 110: Message : R u here yet? I'm wearing blue shirt n black pants. -- Prediction : ['ham']
#
# S.No. 111: Message : Think ur smart ? Win £200 this week in our weekly quiz, text PLAY to 85222 now!T&Cs WinnersClub PO BOX 84, M26 3UZ. 16+. GBP1.50/week -- Prediction : ['spam']
#
# S.No. 112: Message : I wait 4 ü inside da car park... -- Prediction : ['ham']
#
# S.No. 113: Message : How come guoyang go n tell her? Then u told her? -- Prediction : ['ham']
#
# S.No. 114: Message : Horrible bf... I now v hungry... -- Prediction : ['ham']
#
# S.No. 115: Message : I'm done. I'm sorry. I hope your next space gives you everything you want. Remember all the furniture is yours. If i'm not around when you move it, just lock all the locks and leave the key with jenne. -- Prediction : ['ham']
#
# S.No. 116: Message : Wot u up 2? Thout u were gonna call me!! Txt bak luv K -- Prediction : ['ham']
#
# S.No. 117: Message : That's what I love to hear :V see you sundayish, then -- Prediction : ['ham']
#
# S.No. 118: Message : Even i cant close my eyes you are in me our vava playing umma :-D -- Prediction : ['ham']
#
# S.No. 119: Message : Greetings me, ! Consider yourself excused. -- Prediction : ['ham']
#
# S.No. 120: Message : I'm in a movie. Call me 4 wat? -- Prediction : ['ham']
#
# S.No. 121: Message : Okie... Thanx... -- Prediction : ['ham']
#
# S.No. 122: Message : Ask g or iouri, I've told the story like ten times already -- Prediction : ['ham']
#
# S.No. 123: Message : Oi when you gonna ring -- Prediction : ['ham']
#
# S.No. 124: Message : Yar he quite clever but aft many guesses lor. He got ask me 2 bring but i thk darren not so willing 2 go. Aiya they thk leona still not attach wat. -- Prediction : ['ham']
#
# S.No. 125: Message : Huh i cant thk of more oredi how many pages do we have? -- Prediction : ['ham']
#
# S.No. 126: Message : :( but your not here.... -- Prediction : ['ham']
#
# S.No. 127: Message : Tomorrow i am not going to theatre. . . So i can come wherever u call me. . . Tell me where and when to come tomorrow -- Prediction : ['ham']
#
# S.No. 128: Message : Probably earlier than that if the station's where I think it is -- Prediction : ['ham']
#
# S.No. 129: Message : FRAN I DECIDED 2 GO N E WAY IM COMPLETELY BROKE AN KNACKERED I GOT UP BOUT 3 C U 2MRW LOVE JANX P.S THIS IS MY DADS FONE, -NO CREDIT -- Prediction : ['ham']
#
# S.No. 130: Message : K k:) sms chat with me. -- Prediction : ['ham']
#
# S.No. 131: Message : Your gonna be the death if me. I'm gonna leave a note that says its all robs fault. Avenge me. -- Prediction : ['ham']
#
# S.No. 132: Message : I didnt get anything da -- Prediction : ['ham']
#
# S.No. 133: Message : Ummma.will call after check in.our life will begin from qatar so pls pray very hard. -- Prediction : ['ham']
#
# S.No. 134: Message : Let there be snow. Let there be snow. This kind of weather brings ppl together so friendships can grow. -- Prediction : ['ham']
#
# S.No. 135: Message : okmail: Dear Dave this is your final notice to collect your 4* Tenerife Holiday or #5000 CASH award! Call 09061743806 from landline. TCs SAE Box326 CW25WX 150ppm -- Prediction : ['spam']
#
# S.No. 136: Message : Have a nice day my dear. -- Prediction : ['ham']
#
# S.No. 137: Message : I've sent ü my part.. -- Prediction : ['ham']
#
# S.No. 138: Message : Hey , is * rite u put »10 evey mnth is that all? -- Prediction : ['ham']
#
# S.No. 139: Message : Hi Chachi tried calling u now unable to reach u .. Pl give me a missed cal once u c tiz msg  Kanagu -- Prediction : ['ham']
#
# S.No. 140: Message : We still on for tonight? -- Prediction : ['ham']
#
# S.No. 141: Message : If you ask her or she say any please message. -- Prediction : ['ham']
#
# S.No. 142: Message : Tick, tick, tick ... Babe -- Prediction : ['ham']
#
# S.No. 143: Message : I sent them. Do you like? -- Prediction : ['ham']
#
# S.No. 144: Message : Tunji, how's the queen? how are you doing. This is just wishing you a great day. Abiola. -- Prediction : ['ham']
#
# S.No. 145: Message : Ok i shall talk to him -- Prediction : ['ham']
#
# S.No. 146: Message : I'm gonna rip out my uterus. -- Prediction : ['ham']
#
# S.No. 147: Message : Say this slowly.? GOD,I LOVE YOU &amp; I NEED YOU,CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people &amp; u c miracle tomorrow, do it,pls,pls do it... -- Prediction : ['ham']
#
# S.No. 148: Message : Yes just finished watching days of our lives. I love it. -- Prediction : ['ham']
#
# S.No. 149: Message : Dorothy@kiefer.com (Bank of Granite issues Strong-Buy) EXPLOSIVE PICK FOR OUR MEMBERS *****UP OVER 300% *********** Nasdaq Symbol CDGT That is a $5.00 per.. -- Prediction : ['ham']
#
# S.No. 150: Message : Jamster! To get your free wallpaper text HEART to 88888 now! T&C apply. 16 only. Need Help? Call 08701213186. -- Prediction : ['spam']
#
# S.No. 151: Message : S:-)if we have one good partnership going we will take lead:) -- Prediction : ['ham']
#
# S.No. 152: Message : Yeah, we got one lined up for us -- Prediction : ['ham']
#
# S.No. 153: Message : We made it! Eta at taunton is 12:30 as planned, hope that‘s still okday?! Good to see you! :-xx -- Prediction : ['ham']
#
# S.No. 154: Message : Sir, hope your day is going smoothly. i really hoped i wont have to bother you about this. I have some bills that i can't settle this month. I am out of all extra cash. I know this is a challenging time for you also but i have to let you know. -- Prediction : ['ham']
#
# S.No. 155: Message : You please give us connection today itself before  &lt;DECIMAL&gt;  or refund the bill -- Prediction : ['ham']
#
# S.No. 156: Message : No. 1 Nokia Tone 4 ur mob every week! Just txt NOK to 87021. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info -- Prediction : ['spam']
#
# S.No. 157: Message : Meeting u is my work. . . Tel me when shall i do my work tomorrow -- Prediction : ['ham']
#
# S.No. 158: Message : Yeah confirmed for you staying at  that weekend -- Prediction : ['ham']
#
# S.No. 159: Message : You're right I have now that I think about it -- Prediction : ['ham']
#
# S.No. 160: Message : R we still meeting 4 dinner tonight? -- Prediction : ['ham']
#
# S.No. 161: Message : No, I decided that only people who care about stuff vote and caring about stuff is for losers -- Prediction : ['ham']
#
# S.No. 162: Message : Holy living christ what is taking you so long -- Prediction : ['ham']
#
# S.No. 163: Message : Message:some text missing* Sender:Name Missing* *Number Missing *Sent:Date missing *Missing U a lot thats y everything is missing sent via fullonsms.com -- Prediction : ['ham']
#
# S.No. 164: Message : Oops - am at my mum's in somerset... Bit far! Back tomo, see you soon x -- Prediction : ['ham']
#
# S.No. 165: Message : Aiyo please ü got time meh. -- Prediction : ['ham']
#
# S.No. 166: Message : I wish things were different. I wonder when i will be able to show you how much i value you. Pls continue the brisk walks no drugs without askin me please and find things to laugh about. I love you dearly. -- Prediction : ['ham']
#
# S.No. 167: Message : I enjoy watching and playing football and basketball. Anything outdoors. And you? -- Prediction : ['ham']
#
# S.No. 168: Message : Then why you came to hostel. -- Prediction : ['ham']
#
# S.No. 169: Message : Are you this much buzy -- Prediction : ['ham']
#
# S.No. 170: Message : By the way, 'rencontre' is to meet again. Mountains dont.... -- Prediction : ['ham']
#
# S.No. 171: Message : The message sent is askin for  &lt;#&gt; dollars. Shoul i pay  &lt;#&gt;  or  &lt;#&gt; ? -- Prediction : ['ham']
#
# S.No. 172: Message : I'm thinking that chennai forgot to come for auction.. -- Prediction : ['ham']
#
# S.No. 173: Message : My sis is catching e show in e afternoon so i'm not watching w her. So c u wan 2 watch today or tmr lor. -- Prediction : ['ham']
#
# S.No. 174: Message : Its ok..come to my home it vl nice to meet and v can chat.. -- Prediction : ['ham']
#
# S.No. 175: Message : Yo, you around? Just got my car back -- Prediction : ['ham']
#
# S.No. 176: Message : Same to u... -- Prediction : ['ham']
#
# S.No. 177: Message : Up to ü... Ü wan come then come lor... But i din c any stripes skirt... -- Prediction : ['ham']
#
# S.No. 178: Message : Wait 2 min..stand at bus stop -- Prediction : ['ham']
#
# S.No. 179: Message : I know complain num only..bettr directly go to bsnl offc nd apply for it.. -- Prediction : ['ham']
#
# S.No. 180: Message : Do you mind if I ask what happened? You dont have to say if it is uncomfortable. -- Prediction : ['ham']
#
# S.No. 181: Message : The fact that you're cleaning shows you know why i'm upset. Your priority is constantly "what i want to do," not "what i need to do." -- Prediction : ['ham']
#
# S.No. 182: Message : What time you think you'll have it? Need to know when I should be near campus -- Prediction : ['ham']
#
# S.No. 183: Message : Thanks for your ringtone order, reference number X29. Your mobile will be charged 4.50. Should your tone not arrive please call customer services 09065989180 -- Prediction : ['spam']
#
# S.No. 184: Message : I'm in a meeting, call me later at -- Prediction : ['ham']
#
# S.No. 185: Message : No problem with the renewal. I.ll do it right away but i dont know his details. -- Prediction : ['ham']
#
# S.No. 186: Message : If you have belive me. Come to my home. -- Prediction : ['ham']
#
# S.No. 187: Message : Just making dinner, you ? -- Prediction : ['ham']
#
# S.No. 188: Message : Aaooooright are you at work? -- Prediction : ['ham']
#
# S.No. 189: Message : , ,  and  picking them up from various points | going 2 yeovil | and they will do the motor project 4 3 hours | and then u take them home. || 12 2 5.30 max. || Very easy -- Prediction : ['ham']
#
# S.No. 190: Message : My sister cleared two round in birla soft yesterday. -- Prediction : ['ham']
#
# S.No. 191: Message : chile, please! It's only a  &lt;DECIMAL&gt;  hour drive for me. I come down all the time and will be subletting feb-april for audition season. -- Prediction : ['ham']
#
# S.No. 192: Message : Lol you forgot it eh ? Yes, I'll bring it in babe -- Prediction : ['ham']
#
# S.No. 193: Message : I finished my lunch already. U wake up already? -- Prediction : ['ham']
#
# S.No. 194: Message : I want snow. It's just freezing and windy. -- Prediction : ['ham']
#
# S.No. 195: Message : Another month. I need chocolate weed and alcohol. -- Prediction : ['ham']
#
# S.No. 196: Message : Helloooo... Wake up..! "Sweet" "morning" "welcomes" "You" "Enjoy" "This Day" "with full of joy".. "GUD MRNG". -- Prediction : ['ham']
#
# S.No. 197: Message : FreeMsg: Fancy a flirt? Reply DATE now & join the UKs fastest growing mobile dating service. Msgs rcvd just 25p to optout txt stop to 83021. Reply DATE now! -- Prediction : ['spam']
#
# S.No. 198: Message : Macha dont feel upset.i can assume your mindset.believe me one evening with me and i have some wonderful plans for both of us.LET LIFE BEGIN AGAIN.call me anytime -- Prediction : ['ham']
#
# S.No. 199: Message : I was gonna ask you lol but i think its at 7 -- Prediction : ['ham']
#
# S.No. 200: Message : Dear U've been invited to XCHAT. This is our final attempt to contact u! Txt CHAT to 86688 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18 yrs -- Prediction : ['spam']
#
# S.No. 201: Message : IMPORTANT MESSAGE. This is a final contact attempt. You have important messages waiting out our customer claims dept. Expires 13/4/04. Call 08717507382 NOW! -- Prediction : ['spam']
#
# S.No. 202: Message : Raji..pls do me a favour. Pls convey my Birthday wishes to Nimya. Pls. Today is her birthday. -- Prediction : ['ham']
#
# S.No. 203: Message : Yes :)it completely in out of form:)clark also utter waste. -- Prediction : ['ham']
#
# S.No. 204: Message : Mum not going robinson already. -- Prediction : ['ham']
#
# S.No. 205: Message : How dare you stupid. I wont tell anything to you. Hear after i wont talk to you:-. -- Prediction : ['ham']
#
# S.No. 206: Message : Ok. Can be later showing around 8-8:30 if you want + cld have drink before. Wld prefer not to spend money on nosh if you don't mind, as doing that nxt wk. -- Prediction : ['ham']
#
# S.No. 207: Message : So anyways, you can just go to your gym or whatever, my love *smiles* I hope your ok and having a good day babe ... I miss you so much already -- Prediction : ['ham']
#
# S.No. 208: Message : Lol wtf random. Btw is that your lunch break -- Prediction : ['ham']
#
# S.No. 209: Message : Ok lar... Joking wif u oni... -- Prediction : ['ham']
#
# S.No. 210: Message : Ok then i come n pick u at engin? -- Prediction : ['ham']
#
# S.No. 211: Message : I know you are serving. I mean what are you doing now. -- Prediction : ['ham']
#
# S.No. 212: Message : Hello! How r u? Im bored. Inever thought id get bored with the tv but I am. Tell me something exciting has happened there? Anything! =/ -- Prediction : ['ham']
#
# S.No. 213: Message : You'll never believe this but i have actually got off at taunton. Wow -- Prediction : ['ham']
#
# S.No. 214: Message : Do you like shaking your booty on the dance floor? -- Prediction : ['ham']
#
# S.No. 215: Message : Havent still waitin as usual... Ü come back sch oredi? -- Prediction : ['ham']
#
# S.No. 216: Message : Sunshine Hols. To claim ur med holiday send a stamped self address envelope to Drinks on Us UK, PO Box 113, Bray, Wicklow, Eire. Quiz Starts Saturday! Unsub Stop -- Prediction : ['spam']
#
# S.No. 217: Message : He also knows about lunch menu only da. . I know -- Prediction : ['ham']
#
# S.No. 218: Message : Sweet heart how are you? -- Prediction : ['ham']
#
# S.No. 219: Message : Do u knw dis no. &lt;#&gt; ? -- Prediction : ['ham']
#
# S.No. 220: Message : Evening * v good if somewhat event laden. Will fill you in, don't you worry … Head * ok but throat * wrecked. See you at six then! -- Prediction : ['ham']
#
# S.No. 221: Message : Yep. I do like the pink furniture tho. -- Prediction : ['ham']
#
# S.No. 222: Message : My uncles in Atlanta. Wish you guys a great semester. -- Prediction : ['ham']
#
# S.No. 223: Message : I'm ok wif it cos i like 2 try new things. But i scared u dun like mah. Cos u said not too loud. -- Prediction : ['ham']
#
# S.No. 224: Message : Yup i thk they r e teacher said that will make my face look longer. Darren ask me not 2 cut too short. -- Prediction : ['ham']
#
# S.No. 225: Message : Am going to take bath ill place the key in window:-) -- Prediction : ['ham']
#
# S.No. 226: Message : Ok lor then we go tog lor... -- Prediction : ['ham']
#
# S.No. 227: Message : Todays Voda numbers ending 5226 are selected to receive a ?350 award. If you hava a match please call 08712300220 quoting claim code 1131 standard rates app  -- Prediction : ['spam']
#
# S.No. 228: Message : Hi good mornin.. Thanku wish u d same.. -- Prediction : ['ham']
#
# S.No. 229: Message : I'm not sure if its still available though -- Prediction : ['ham']
#
# S.No. 230: Message : How do you guys go to see movies on your side. -- Prediction : ['ham']
#
# S.No. 231: Message : Shhhhh nobody is supposed to know! -- Prediction : ['ham']
#
# S.No. 232: Message : Oooh bed ridden ey? What are YOU thinking of? -- Prediction : ['ham']
#
# S.No. 233: Message : Sorry that was my uncle. I.ll keep in touch -- Prediction : ['ham']
#
# S.No. 234: Message : Tessy..pls do me a favor. Pls convey my birthday wishes to Nimya..pls dnt forget it. Today is her birthday Shijas -- Prediction : ['ham']
#
# S.No. 235: Message : I had been hoping i would not have to send you this message. My rent is due and i dont have enough for it. My reserves are completely gone. Its a loan i need and was hoping you could her. The balance is  &lt;#&gt; . Is there a way i could get that from you, till mid march when i hope to pay back. -- Prediction : ['ham']
#
# S.No. 236: Message : Then why you not responding -- Prediction : ['ham']
#
# S.No. 237: Message : Boo what time u get out? U were supposed to take me shopping today. :( -- Prediction : ['ham']
#
# S.No. 238: Message : I'm already back home so no probably not -- Prediction : ['ham']
#
# S.No. 239: Message : Howz that persons story -- Prediction : ['ham']
#
# S.No. 240: Message : I've reached sch already... -- Prediction : ['ham']
#
# S.No. 241: Message : I can't describe how lucky you are that I'm actually awake by noon -- Prediction : ['ham']
#
# S.No. 242: Message : Got what it takes 2 take part in the WRC Rally in Oz? U can with Lucozade Energy! Text RALLY LE to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u! -- Prediction : ['ham']
#
# S.No. 243: Message : Oh gei. That happend to me in tron. Maybe ill dl it in 3d when its out -- Prediction : ['ham']
#
# S.No. 244: Message : Does cinema plus drink appeal tomo? * Is a fr thriller by director i like on at mac at 8.30. -- Prediction : ['ham']
#
# S.No. 245: Message : Cab is available.they pick up and drop at door steps. -- Prediction : ['ham']
#
# S.No. 246: Message : You will be in the place of that man -- Prediction : ['ham']
#
# S.No. 247: Message : Hi Jon, Pete here, Ive bin 2 Spain recently & hav sum dinero left, Bill said u or ur rents mayb interested in it, I hav 12,000pes, so around £48, tb, James. -- Prediction : ['ham']
#
# S.No. 248: Message : Was it something u ate? -- Prediction : ['ham']
#
# S.No. 249: Message : <Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS alert. You have 4 messages. You have 21 matches. Please call back on 09056242159 to retrieve your messages and matches -- Prediction : ['ham']
#
# S.No. 250: Message : Let me know how it changes in the next 6hrs. It can even be appendix but you are out of that age range. However its not impossible. So just chill and let me know in 6hrs -- Prediction : ['ham']
#
# S.No. 251: Message : I think i am disturbing her da -- Prediction : ['ham']
#
# S.No. 252: Message : Is toshiba portege m100 gd? -- Prediction : ['ham']
#
# S.No. 253: Message : What should i eat fo lunch senor -- Prediction : ['ham']
#
# S.No. 254: Message : This single single answers are we fighting? Plus i said am broke and you didnt reply -- Prediction : ['ham']
#
# S.No. 255: Message : Some are lasting as much as 2 hours. You might get lucky. -- Prediction : ['ham']
#
# S.No. 256: Message : Hi its Kate it was lovely to see you tonight and ill phone you tomorrow. I got to sing and a guy gave me his card! xxx -- Prediction : ['ham']
#
# S.No. 257: Message : Gudnite....tc...practice going on -- Prediction : ['ham']
#
# S.No. 258: Message : Yup... How ü noe leh... -- Prediction : ['ham']
#
# S.No. 259: Message : Ok Chinese food on its way. When I get fat you're paying for my lipo. -- Prediction : ['ham']
#
# S.No. 260: Message : FreeMsg: Claim ur 250 SMS messages-Text OK to 84025 now!Use web2mobile 2 ur mates etc. Join Txt250.com for 1.50p/wk. T&C BOX139, LA32WU. 16 . Remove txtX or stop -- Prediction : ['spam']
#
# S.No. 261: Message : He says he'll give me a call when his friend's got the money but that he's definitely buying before the end of the week -- Prediction : ['ham']
#
# S.No. 262: Message : Cool, we shall go and see, have to go to tip anyway. Are you at home, got something to drop in later? So lets go to town tonight! Maybe mum can take us in. -- Prediction : ['ham']
#
# S.No. 263: Message : Ever green quote ever told by Jerry in cartoon "A Person Who Irritates u Always Is the one Who Loves u Vry Much But Fails to Express It...!..!! :-) :-) gud nyt -- Prediction : ['ham']
#
# S.No. 264: Message : Ok... Thanx... Gd nite 2 ü too... -- Prediction : ['ham']
#
# S.No. 265: Message : I might come to kerala for 2 days.so you can be prepared to take a leave once i finalise .dont plan any travel during my visit.need to finish urgent works. -- Prediction : ['ham']
#
# S.No. 266: Message : Your account has been refilled successfully by INR  &lt;DECIMAL&gt; . Your KeralaCircle prepaid account balance is Rs  &lt;DECIMAL&gt; . Your Transaction ID is KR &lt;#&gt; . -- Prediction : ['ham']
#
# S.No. 267: Message : Not much, just some textin'. How bout you? -- Prediction : ['ham']
#
# S.No. 268: Message : Good morning, my boytoy! How's those yummy lips ? Where's my sexy buns now ? What do you do ? Do you think of me ? Do you crave me ? Do you need me ? -- Prediction : ['ham']
#
# S.No. 269: Message : And is there a way you can send shade's stuff to her. And she has been wonderful too. -- Prediction : ['ham']
#
# S.No. 270: Message : PRIVATE! Your 2003 Account Statement for 07808247860 shows 800 un-redeemed S. I. M. points. Call 08719899229 Identifier Code: 40411 Expires 06/11/04 -- Prediction : ['spam']
#
# S.No. 271: Message : Ok i am on the way to home hi hi -- Prediction : ['ham']
#
# S.No. 272: Message : G says you never answer your texts, confirm/deny -- Prediction : ['ham']
#
# S.No. 273: Message : You will be receiving this week's Triple Echo ringtone shortly. Enjoy it! -- Prediction : ['ham']
#
# S.No. 274: Message : +123 Congratulations - in this week's competition draw u have won the £1450 prize to claim just call 09050002311 b4280703. T&Cs/stop SMS 08718727868. Over 18 only 150ppm -- Prediction : ['spam']
#
# S.No. 275: Message : House-Maid is the murderer, coz the man was murdered on  &lt;#&gt; th January.. As public holiday all govt.instituitions are closed,including post office..understand? -- Prediction : ['ham']
#
# S.No. 276: Message : That's one of the issues but california is okay. No snow so its manageable -- Prediction : ['ham']
#
# S.No. 277: Message : I'm okay. Chasing the dream. What's good. What are you doing next. -- Prediction : ['ham']
#
# S.No. 278: Message : I think i've fixed it can you send a test message? -- Prediction : ['ham']
#
# S.No. 279: Message : U don't remember that old commercial? -- Prediction : ['ham']
#
# S.No. 280: Message : Esplanade lor. Where else... -- Prediction : ['ham']
#
# S.No. 281: Message : I lost 4 pounds since my doc visit last week woot woot! Now I'm gonna celebrate by stuffing my face! -- Prediction : ['ham']
#
# S.No. 282: Message : Wat makes some people dearer is not just de happiness dat u feel when u meet them but de pain u feel when u miss dem!!! -- Prediction : ['ham']
#
# S.No. 283: Message : Miss call miss call khelate kintu opponenter miss call dhorte lage. Thats d rule. One with great phone receiving quality wins. -- Prediction : ['ham']
#
# S.No. 284: Message : Xy trying smth now. U eat already? We havent... -- Prediction : ['ham']
#
# S.No. 285: Message : 449050000301 You have won a £2,000 price! To claim, call 09050000301. -- Prediction : ['spam']
#
# S.No. 286: Message : Ard 6 like dat lor. -- Prediction : ['ham']
#
# S.No. 287: Message : Yo sorry was in the shower sup -- Prediction : ['ham']
#
# S.No. 288: Message : Ok thanx... Take care then... -- Prediction : ['ham']
#
# S.No. 289: Message : Oh ic. I thought you meant mary jane. -- Prediction : ['ham']
#
# S.No. 290: Message : Sorry battery died, yeah I'm here -- Prediction : ['ham']
#
# S.No. 291: Message : I hope your alright babe? I worry that you might have felt a bit desparate when you learned the job was a fake ? I am here waiting when you come back, my love -- Prediction : ['ham']
#
# S.No. 292: Message : Printer is cool. I mean groovy. Wine is groovying -- Prediction : ['ham']
#
# S.No. 293: Message : Good morning. At the repair shop--the ONLY reason i'm up at this hour. -- Prediction : ['ham']
#
# S.No. 294: Message : And also I've sorta blown him off a couple times recently so id rather not text him out of the blue looking for weed -- Prediction : ['ham']
#
# S.No. 295: Message : I am in your office na. -- Prediction : ['ham']
#
# S.No. 296: Message : I can't right this second, gotta hit people up first -- Prediction : ['ham']
#
# S.No. 297: Message : Hi kindly give us back our documents which we submitted for loan from STAPATI -- Prediction : ['ham']
#
# S.No. 298: Message : HEY DAS COOL... IKNOW ALL 2 WELLDA PERIL OF STUDENTFINANCIAL CRISIS!SPK 2 U L8R. -- Prediction : ['ham']
#
# S.No. 299: Message : URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm -- Prediction : ['spam']
#
# S.No. 300: Message : Probably not, I'm almost out of gas and I get some cash tomorrow -- Prediction : ['ham']
#
# S.No. 301: Message : Just checked out, heading out to drop off my stuff now -- Prediction : ['ham']
#
# S.No. 302: Message : Have you not finished work yet or something? -- Prediction : ['ham']
#
# S.No. 303: Message : Pete can you please ring meive hardly gotany credit -- Prediction : ['ham']
#
# S.No. 304: Message : Usually the body takes care of it buy making sure it doesnt progress. Can we pls continue this talk on saturday. -- Prediction : ['ham']
#
# S.No. 305: Message : Just hopeing that wasn‘t too pissed up to remember and has gone off to his sisters or something! -- Prediction : ['ham']
#
# S.No. 306: Message : How i noe... Did ü specify da domain as nusstu... Ü still in sch... -- Prediction : ['ham']
#
# S.No. 307: Message : Someone has contacted our dating service and entered your phone becausethey fancy you! To find out who it is call from a landline 09058098002. PoBox1, W14RG 150p -- Prediction : ['spam']
#
# S.No. 308: Message : Feel like trying kadeem again? :V -- Prediction : ['ham']
#
# S.No. 309: Message : The sign of maturity is not when we start saying big things.. But actually it is, when we start understanding small things... *HAVE A NICE EVENING* BSLVYL -- Prediction : ['ham']
#
# S.No. 310: Message : Ok . . now i am in bus. . If i come soon i will come otherwise tomorrow -- Prediction : ['ham']
#
# S.No. 311: Message : Please CALL 08712402902 immediately as there is an urgent message waiting for you. -- Prediction : ['spam']
#
# S.No. 312: Message : Beautiful Truth against Gravity.. Read carefully: "Our heart feels light when someone is in it.. But it feels very heavy when someone leaves it.." GOODMORNING -- Prediction : ['ham']
#
# S.No. 313: Message : Fuck babe ... What happened to you ? How come you never came back? -- Prediction : ['ham']
#
# S.No. 314: Message : Send me your resume:-) -- Prediction : ['ham']
#
# S.No. 315: Message : How are you doing. How's the queen. Are you going for the royal wedding -- Prediction : ['ham']
#
# S.No. 316: Message : Thx. All will be well in a few months -- Prediction : ['ham']
#
# S.No. 317: Message : Hey! do u fancy meetin me at 4 at cha  hav a lil beverage on me. if not txt or ring me and we can meet up l8r. quite tired got in at 3 v.pist ;) love Pete x x x -- Prediction : ['ham']
#
# S.No. 318: Message : Correct. So how was work today -- Prediction : ['ham']
#
# S.No. 319: Message : I've got ten bucks, jay is being noncomittal -- Prediction : ['ham']
#
# S.No. 320: Message : Night has ended for another day, morning has come in a special way. May you smile like the sunny rays and leaves your worries at the blue blue bay. -- Prediction : ['ham']
#
# S.No. 321: Message : FROM 88066 LOST £12 HELP -- Prediction : ['ham']
#
# S.No. 322: Message : Dear are you angry i was busy dear -- Prediction : ['ham']
#
# S.No. 323: Message : Derp. Which is worse, a dude who always wants to party or a dude who files a complaint about the three drug abusers he lives with -- Prediction : ['ham']
#
# S.No. 324: Message : Ok no prob -- Prediction : ['ham']
#
# S.No. 325: Message : Yo dude guess who just got arrested the other day -- Prediction : ['ham']
#
# S.No. 326: Message : K. Did you call me just now ah?  -- Prediction : ['ham']
#
# S.No. 327: Message : Haf u eaten? Wat time u wan me 2 come? -- Prediction : ['ham']
#
# S.No. 328: Message : Rose for red,red for blood,blood for heart,heart for u. But u for me.... Send tis to all ur friends.. Including me.. If u like me.. If u get back, 1-u r poor in relation! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5+- some1 is praying god to marry u.:-) try it.... -- Prediction : ['ham']
#
# S.No. 329: Message : What happen to her tell the truth -- Prediction : ['ham']
#
# S.No. 330: Message : Hi there, 2nights ur lucky night! Uve been invited 2 XCHAT, the Uks wildest chat! Txt CHAT to 86688 now! 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18yrs -- Prediction : ['spam']
#
# S.No. 331: Message : Sorry, I'll call later -- Prediction : ['ham']
#
# S.No. 332: Message : Small problem in auction:)punj now asking tiwary -- Prediction : ['ham']
#
# S.No. 333: Message : Ok... -- Prediction : ['ham']
#
# S.No. 334: Message : Say this slowly.? GOD,I LOVE YOU &amp; I NEED YOU,CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people &amp; u c miracle tomorrow, do it,pls,pls do it... -- Prediction : ['ham']
#
# S.No. 335: Message : Shit that is really shocking and scary, cant imagine for a second. Def up for night out. Do u think there is somewhere i could crash for night, save on taxi? -- Prediction : ['ham']
#
# S.No. 336: Message : No that just means you have a fat head -- Prediction : ['ham']
#
# S.No. 337: Message : Hello. They are going to the village pub at 8 so either come here or there accordingly. Ok? -- Prediction : ['ham']
#
# S.No. 338: Message : Good afternoon on this glorious anniversary day, my sweet J !! I hope this finds you happy and content, my Prey. I think of you and send a teasing kiss from across the sea coaxing images of fond souveniers ... You Cougar-Pen -- Prediction : ['ham']
#
# S.No. 339: Message : Its good, we'll find a way -- Prediction : ['ham']
#
# S.No. 340: Message : Boy; I love u Grl: Hogolo Boy: gold chain kodstini Grl: Agalla Boy: necklace madstini Grl: agalla Boy: Hogli 1 mutai eerulli kodthini! Grl: I love U kano;-) -- Prediction : ['ham']
#
# S.No. 341: Message : 2 celebrate my bday, y else? -- Prediction : ['ham']
#
# S.No. 342: Message : Doing my masters. When will you buy a bb cos i have for sale and how's bf -- Prediction : ['ham']
#
# S.No. 343: Message : Hey...Great deal...Farm tour 9am to 5pm $95/pax, $50 deposit by 16 May -- Prediction : ['ham']
#
# S.No. 344: Message : Monthly password for wap. mobsi.com is 391784. Use your wap phone not PC. -- Prediction : ['ham']
#
# S.No. 345: Message : Hey tmr maybe can meet you at yck -- Prediction : ['ham']
#
# S.No. 346: Message : Havent. -- Prediction : ['ham']
#
# S.No. 347: Message : That seems unnecessarily affectionate -- Prediction : ['ham']
#
# S.No. 348: Message : Hi. Happy New Year. I dont mean to intrude but can you pls let me know how much tuition you paid last semester and how much this semester is. Thanks -- Prediction : ['ham']
#
# S.No. 349: Message : That depends. How would you like to be treated? :) -- Prediction : ['ham']
#
# S.No. 350: Message : Kinda. First one gets in at twelve! Aah. Speak tomo -- Prediction : ['ham']
#
# S.No. 351: Message : Someone U know has asked our dating service 2 contact you! Cant Guess who? CALL 09058091854 NOW all will be revealed. PO BOX385 M6 6WU -- Prediction : ['spam']
# S.No. 352: Message : Its ok., i just askd did u knw tht no? -- Prediction : ['ham']
#
# S.No. 353: Message : He is world famamus.... -- Prediction : ['ham']
#
# S.No. 354: Message : 09066362231 URGENT! Your mobile No 07xxxxxxxxx won a £2,000 bonus caller prize on 02/06/03! this is the 2nd attempt to reach YOU! call 09066362231 ASAP! -- Prediction : ['spam']
#
# S.No. 355: Message : Arun can u transfr me d amt -- Prediction : ['ham']
#
# S.No. 356: Message : Nite... -- Prediction : ['ham']
#
# S.No. 357: Message : I sent your maga that money yesterday oh. -- Prediction : ['ham']
#
# S.No. 358: Message : I liked your new house -- Prediction : ['ham']
#
# S.No. 359: Message : Gettin rdy to ship comp -- Prediction : ['ham']
#
# S.No. 360: Message : Also track down any lighters you can find -- Prediction : ['ham']
#
# S.No. 361: Message : Then ur sis how? -- Prediction : ['ham']
#
# S.No. 362: Message : U too... -- Prediction : ['ham']
#
# S.No. 363: Message : U really pig leh sleep so much. My dad wake me up at 10 smth 2 eat lunch today. -- Prediction : ['ham']
#
# S.No. 364: Message : Watching cartoon, listening music &amp; at eve had to go temple &amp; church.. What about u? -- Prediction : ['ham']
#
# S.No. 365: Message : I pocked you up there before -- Prediction : ['ham']
#
# S.No. 366: Message : Then we gotta do it after that -- Prediction : ['ham']
#
# S.No. 367: Message : Not thought bout it... || Drink in tap & spile at seven. || Is that pub on gas st off broad st by canal. || Ok? -- Prediction : ['ham']
#
# S.No. 368: Message : Call me, i am senthil from hsbc. -- Prediction : ['ham']
#
# S.No. 369: Message : Company is very good.environment is terrific and food is really nice:) -- Prediction : ['ham']
#
# S.No. 370: Message : I think just yourself …Thanks and see you tomo -- Prediction : ['ham']
#
# S.No. 371: Message : No shit, but I wasn't that surprised, so I went and spent the evening with that french guy I met in town here and we fooled around a bit but I didn't let him fuck me -- Prediction : ['ham']
#
# S.No. 372: Message : Ü only send me the contents page... -- Prediction : ['ham']
#
# S.No. 373: Message : It certainly puts things into perspective when something like this happens -- Prediction : ['ham']
#
# S.No. 374: Message : Only 2% students solved this CAT question in 'xam... 5+3+2= &lt;#&gt;  9+2+4= &lt;#&gt;  8+6+3= &lt;#&gt;  then 7+2+5=????? Tell me the answer if u r brilliant...1thing.i got d answr. -- Prediction : ['ham']
#
# S.No. 375: Message : I'm at home n ready... -- Prediction : ['ham']
#
# S.No. 376: Message : We got a divorce. Lol. She.s here -- Prediction : ['ham']
#
# S.No. 377: Message : Goodmorning today i am late for  &lt;DECIMAL&gt; min. -- Prediction : ['ham']
#
# S.No. 378: Message : Thinkin about someone is all good. No drugs for that -- Prediction : ['ham']
#
# S.No. 379: Message : What your plan for pongal? -- Prediction : ['ham']
#
# S.No. 380: Message : Sorry man my account's dry or I would, if you want we could trade back half or I could buy some shit with my credit card -- Prediction : ['ham']
#
# S.No. 381: Message : Sorry, I'll call later -- Prediction : ['ham']
#
# S.No. 382: Message : Dear we are going to our rubber place -- Prediction : ['ham']
#
# S.No. 383: Message : Im cool ta luv but v.tired 2 cause i have been doin loads of planning all wk, we have got our social services inspection at the nursery! Take care & spk sn x. -- Prediction : ['ham']
#
# S.No. 384: Message : Oh. U must have taken your REAL Valentine out shopping first. -- Prediction : ['ham']
#
# S.No. 385: Message : Minimum walk is 3miles a day. -- Prediction : ['ham']
#
# S.No. 386: Message : In e msg jus now. U said thanks for gift. -- Prediction : ['ham']
#
# S.No. 387: Message : Just sent again. Do you scream and moan in bed, princess? -- Prediction : ['ham']
#
# S.No. 388: Message : Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records -- Prediction : ['spam']
#
# S.No. 389: Message : Plz note: if anyone calling from a mobile Co. &amp; asks u to type # &lt;#&gt;  or # &lt;#&gt; . Do not do so. Disconnect the call,coz it iz an attempt of 'terrorist' to make use of the sim card no. Itz confirmd by nokia n motorola n has been verified by CNN IBN. -- Prediction : ['ham']
#
# ...
#
# S.No. 1265: Message : Me too! Have a lovely night xxx -- Prediction : ['ham']
#
# S.No. 1266: Message : I couldn't say no as he is a dying man and I feel sad for him so I will go and I just wanted you to know I would probably be gone late into your night -- Prediction : ['ham']
#
# S.No. 1267: Message : Lol yes. Our friendship is hanging on a thread cause u won't buy stuff. -- Prediction : ['ham']
#
# S.No. 1268: Message : Ball is moving a lot.will spin in last :)so very difficult to bat:) -- Prediction : ['ham']
#
# S.No. 1269: Message : R u still working now? -- Prediction : ['ham']
#
# S.No. 1270: Message : I'm at home. Please call -- Prediction : ['ham']
#
# S.No. 1271: Message : I've got  &lt;#&gt; , any way I could pick up? -- Prediction : ['ham']
#
# S.No. 1272: Message : Congratulations! Thanks to a good friend U have WON the £2,000 Xmas prize. 2 claim is easy, just call 08718726978 NOW! Only 10p per minute. BT-national-rate -- Prediction : ['spam']
#
# S.No. 1273: Message : Sir, i am waiting for your call. -- Prediction : ['ham']
#
# S.No. 1274: Message : Wewa is 130. Iriver 255. All 128 mb. -- Prediction : ['ham']
#
# S.No. 1275: Message : Yes! How is a pretty lady like you single? -- Prediction : ['ham']
#
# S.No. 1276: Message : Yeah, we can probably swing by once my roommate finishes up with his girl -- Prediction : ['ham']
#
# S.No. 1277: Message : Hey whats up? U sleeping all morning? -- Prediction : ['ham']
#
# S.No. 1278: Message : Yup i've finished c ü there... -- Prediction : ['ham']
#
# S.No. 1279: Message : Never blame a day in ur life. Good days give u happiness. Bad days give u experience. Both are essential in life! All are Gods blessings! good morning.: -- Prediction : ['ham']
#
# S.No. 1280: Message : I REALLY NEED 2 KISS U I MISS U MY BABY FROM UR BABY 4EVA -- Prediction : ['ham']
#
# S.No. 1281: Message : Aiyo... U always c our ex one... I dunno abt mei, she haven reply... First time u reply so fast... Y so lucky not workin huh, got bao by ur sugardad ah...gee..  -- Prediction : ['ham']
#
# S.No. 1282: Message : What makes you most happy? -- Prediction : ['ham']
#
# S.No. 1283: Message : When you came to hostel. -- Prediction : ['ham']
#
# S.No. 1284: Message : I went to project centre -- Prediction : ['ham']
#
# S.No. 1285: Message : K...k:)why cant you come here and search job:) -- Prediction : ['ham']
#
# S.No. 1286: Message : we tried to contact you re your response to our offer of a new nokia fone and camcorder hit reply or call 08000930705 for delivery -- Prediction : ['spam']
#
# S.No. 1287: Message : Howz that persons story -- Prediction : ['ham']
#
# S.No. 1288: Message : Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access! -- Prediction : ['ham']
#
# S.No. 1289: Message : I sent you  &lt;#&gt;  bucks -- Prediction : ['ham']
#
# S.No. 1290: Message : Going to take your babe out ? -- Prediction : ['ham']
#
# S.No. 1291: Message : That's cause your old. I live to be high. -- Prediction : ['ham']
#
# S.No. 1292: Message : Dear umma she called me now :-) -- Prediction : ['ham']
#
# S.No. 1293: Message : Each Moment in a day,has its own value-Morning brings hope,afternoon brings faith,Evening brings luv,Night brings rest,Wish u find them all today.Good Morning -- Prediction : ['ham']
#
# S.No. 1294: Message : Hiya do u like the hlday pics looked horrible in them so took mo out! Hows the camp Amrca thing? Speak soon Serena:) -- Prediction : ['ham']
#
# S.No. 1295: Message : I'll probably be around mu a lot -- Prediction : ['ham']
#
# S.No. 1296: Message : The world's most happiest frnds never have the same characters... Dey just have the best understanding of their differences... -- Prediction : ['ham']
#
# S.No. 1297: Message : Good afternoon, my love. How goes your day ? What are you up to ? I woke early and am online waiting for you ... Hmmm ... Italian boy is online I see . *grins* -- Prediction : ['ham']
#
# S.No. 1298: Message : Think I could stop by in like an hour or so? My roommate's looking to stock up for a trip -- Prediction : ['ham']
#
# S.No. 1299: Message : I surely dont forgot to come:)i will always be in touch in with you:-) -- Prediction : ['ham']
#
# S.No. 1300: Message : Thats cool. Where should i cum? On you or in you? :) -- Prediction : ['ham']
#
# S.No. 1301: Message : WIN a £200 Shopping spree every WEEK Starting NOW. 2 play text STORE to 88039. SkilGme. TsCs08714740323 1Winawk! age16 £1.50perweeksub. -- Prediction : ['spam']
#
# S.No. 1302: Message : How much for an eighth? -- Prediction : ['ham']
#
# S.No. 1303: Message : PISS IS TALKING IS SOMEONE THAT REALISE U THAT POINT THIS AT IS IT.(NOW READ IT BACKWARDS) -- Prediction : ['ham']
#
# S.No. 1304: Message : Ok. But i finish at 6. -- Prediction : ['ham']
#
# S.No. 1305: Message : SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info -- Prediction : ['spam']
#
# S.No. 1306: Message : Raviyog Peripherals bhayandar east -- Prediction : ['ham']
#
# S.No. 1307: Message : This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize. 2 claim is easy, call 08718726970 NOW! Only 10p per min. BT-national-rate  -- Prediction : ['spam']
#
# S.No. 1308: Message : Are you ok. What happen to behave like this -- Prediction : ['ham']
#
# S.No. 1309: Message : Hmm, too many of them unfortunately... Pics obviously arent hot cakes. Its kinda fun tho -- Prediction : ['ham']
#
# S.No. 1310: Message : 85233 FREE>Ringtone!Reply REAL -- Prediction : ['spam']
#
# S.No. 1311: Message : Buzzzz! *grins* Did I buzz your ass? Buzz your chest ? Buzz your cock ? Where do you keep your phone ? Is the vibrator on ? Did you feel it shake ? -- Prediction : ['ham']
#
# S.No. 1312: Message : Okey dokey, i‘ll be over in a bit just sorting some stuff out. -- Prediction : ['ham']
#
# S.No. 1313: Message : Or ill be a little closer like at the bus stop on the same street -- Prediction : ['ham']
#
# S.No. 1314: Message : Why is that, princess? I bet the brothas are all chasing you! -- Prediction : ['ham']
#
# S.No. 1315: Message : Hmm...my uncle just informed me that he's paying the school directly. So pls buy food. -- Prediction : ['ham']
#
# S.No. 1316: Message : K:)eng rocking in ashes:) -- Prediction : ['ham']
#
# S.No. 1317: Message : The 2 oz guy is being kinda flaky but one friend is interested in picking up $ &lt;#&gt;  worth tonight if possible -- Prediction : ['ham']
#
# S.No. 1318: Message : Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game! Text TONE or FLAG to 84199. Optout txt ENG STOP Box39822 W111WX £1.50 -- Prediction : ['spam']
#
# S.No. 1319: Message : No he didn't. Spring is coming early yay! -- Prediction : ['ham']
#
# S.No. 1320: Message : Is that on the telly? No its Brdget Jones! -- Prediction : ['ham']
#
# S.No. 1321: Message : I would but I'm still cozy. And exhausted from last night.nobody went to school or work. Everything is closed. -- Prediction : ['ham']
#
# S.No. 1322: Message : Hai priya are you right. What doctor said pa. Where are you. -- Prediction : ['ham']
#
# S.No. 1323: Message : I want to lick your pussy now... -- Prediction : ['ham']
#
# S.No. 1324: Message : I will come with karnan car. Please wait till 6pm will directly goto doctor. -- Prediction : ['ham']
#
# S.No. 1325: Message : Can you use foreign stamps for whatever you send them off for?  -- Prediction : ['ham']
#
# S.No. 1326: Message : Umma my life and vava umma love you lot dear -- Prediction : ['ham']
#
# S.No. 1327: Message : You always make things bigger than they are -- Prediction : ['ham']
#
# S.No. 1328: Message : A boy was late 2 home. His father: "POWER OF FRNDSHIP" -- Prediction : ['ham']
#
# S.No. 1329: Message : So that means you still think of teju -- Prediction : ['ham']
#
# S.No. 1330: Message : Joy's father is John. Then John is the ____ of Joy's father. If u ans ths you hav  &lt;#&gt;  IQ. Tis s IAS question try to answer. -- Prediction : ['ham']
#
# S.No. 1331: Message : Its worse if if uses half way then stops. Its better for him to complete it. -- Prediction : ['ham']
#
# S.No. 1332: Message : Argh my 3g is spotty, anyway the only thing I remember from the research we did was that province and sterling were the only problem-free places we looked at -- Prediction : ['ham']
#
# S.No. 1333: Message : No. I dont want to hear anything -- Prediction : ['ham']
#
# S.No. 1334: Message : We live in the next  &lt;#&gt; mins -- Prediction : ['ham']
#
# S.No. 1335: Message : I guess that's why you re worried. You must know that there's a way the body repairs itself. And i'm quite sure you shouldn't worry. We'll take it slow. First the tests, they will guide when your ovulation is then just relax. Nothing you've said is a reason to worry but i.ll keep on followin you up. -- Prediction : ['ham']
#
# S.No. 1336: Message : Im in inperialmusic listening2the weirdest track ever byleafcutter john-sounds like insects being molested&someone plumbing,remixed by evil men on acid! -- Prediction : ['ham']
#
# S.No. 1337: Message : Tell your friends what you plan to do on Valentines day @ &lt;URL&gt; -- Prediction : ['ham']
#
# S.No. 1338: Message : Mm yes dear look how i am hugging you both. :-P -- Prediction : ['ham']
#
# S.No. 1339: Message : Yup ok thanx... -- Prediction : ['ham']
#
# S.No. 1340: Message : Can't. I feel nauseous. I'm so pissed. I didn't eat any sweets all week cause today I was planning to pig out. I was dieting all week. And now I'm not hungry :/ -- Prediction : ['ham']
#
# S.No. 1341: Message : Fun fact: although you would think armand would eventually build up a tolerance or some shit considering how much he smokes, he gets fucked up in like 2 hits -- Prediction : ['ham']
#
# S.No. 1342: Message : Hey gals...U all wanna meet 4 dinner at nìte?  -- Prediction : ['ham']
#
# S.No. 1343: Message : You are being contacted by our dating service by someone you know! To find out who it is, call from a land line 09050000878. PoBox45W2TG150P -- Prediction : ['spam']
#
# S.No. 1344: Message : Not yet chikku..going to room nw, i'm in bus.. -- Prediction : ['ham']
#
# S.No. 1345: Message : Olol i printed out a forum post by a guy with the exact same  prob which was fixed with a gpu replacement. Hopefully they dont ignore that. -- Prediction : ['ham']
#
# S.No. 1346: Message : Someone U know has asked our dating service 2 contact you! Cant guess who? CALL 09058095107 NOW all will be revealed. POBox 7, S3XY 150p  -- Prediction : ['spam']
#
# S.No. 1347: Message : Why you keeping me away like this -- Prediction : ['ham']
#
# S.No. 1348: Message : CLAIRE here am havin borin time & am now alone U wanna cum over 2nite? Chat now 09099725823 hope 2 C U Luv CLAIRE xx Calls£1/minmoremobsEMSPOBox45PO139WA -- Prediction : ['ham']
#
# S.No. 1349: Message : Hmmm.still we dont have opener? -- Prediction : ['ham']
#
# S.No. 1350: Message : Well done, blimey, exercise, yeah, i kinda remember wot that is, hmm.  -- Prediction : ['ham']
#
# S.No. 1351: Message : No de. But call me after some time. Ill tell you k -- Prediction : ['ham']
#
# S.No. 1352: Message : K I'll be sure to get up before noon and see what's what -- Prediction : ['ham']
#
# S.No. 1353: Message : URGENT! This is the 2nd attempt to contact U!U have WON £1000CALL 09071512432 b4 300603t&csBCM4235WC1N3XX.callcost150ppmmobilesvary. max£7. 50 -- Prediction : ['spam']
#
# S.No. 1354: Message : S.i'm watching it in live.. -- Prediction : ['ham']
#
# S.No. 1355: Message : Miserable. They don't tell u that the side effects of birth control are massive gut wrenching cramps for the first 2 months. I didn't sleep at all last night. -- Prediction : ['ham']
#
# S.No. 1356: Message : Who were those people ? Were you in a tour ? I thought you were doing that sofa thing you sent me ? Your curious sugar -- Prediction : ['ham']
#
# S.No. 1357: Message : Aight, text me tonight and we'll see what's up -- Prediction : ['ham']
#
# S.No. 1358: Message : Havent shopping now lor i juz arrive only -- Prediction : ['ham']
#
# S.No. 1359: Message : Finally the match heading towards draw as your prediction. -- Prediction : ['ham']
#
# S.No. 1360: Message : That's y u haf 2 keep me busy... -- Prediction : ['ham']
#
# S.No. 1361: Message : R U &SAM P IN EACHOTHER. IF WE MEET WE CAN GO 2 MY HOUSE -- Prediction : ['ham']
#
# S.No. 1362: Message : Yup but not studying surfing lor. I'm in e lazy mode today. -- Prediction : ['ham']
#
# S.No. 1363: Message : Just sleeping..and surfing -- Prediction : ['ham']
#
# S.No. 1364: Message : Cps is causing the outages to conserve energy. -- Prediction : ['ham']
#
# S.No. 1365: Message : Can you plz tell me the ans. BSLVYL sent via fullonsms.com -- Prediction : ['ham']
#
# S.No. 1366: Message : How much she payed. Suganya. -- Prediction : ['ham']
#
# S.No. 1367: Message : My sister in law, hope you are having a great month. Just saying hey. Abiola -- Prediction : ['ham']
#
# S.No. 1368: Message : Bognor it is! Should be splendid at this time of year. -- Prediction : ['ham']
#
# S.No. 1369: Message : S da..al r above  &lt;#&gt; -- Prediction : ['ham']
#
# S.No. 1370: Message : But if she.s drinkin i'm ok. -- Prediction : ['ham']
#
# S.No. 1371: Message : Tell you what, if you make a little spreadsheet and track whose idea it was to smoke to determine who "smokes too much" for the entire month of february, I'll come up -- Prediction : ['ham']
#
# S.No. 1372: Message : I got a call from a landline number. . . I am asked to come to anna nagar . . . I will go in the afternoon -- Prediction : ['ham']
#
# S.No. 1373: Message : I need to come home and give you some good lovin... -- Prediction : ['ham']
#
# S.No. 1374: Message : Am slow in using biola's fne -- Prediction : ['ham']
#
# S.No. 1375: Message : K so am I, how much for an 8th? Fifty? -- Prediction : ['ham']
#
# S.No. 1376: Message : K... Must book a not huh? so going for yoga basic on sunday? -- Prediction : ['ham']
#
# S.No. 1377: Message : Hey sorry I didntgive ya a a bellearlier hunny,just been in bedbut mite go 2 thepub l8tr if uwana mt up?loads a luv Jenxxx. -- Prediction : ['ham']
#
# S.No. 1378: Message : URGENT! Your mobile No 07xxxxxxxxx won a £2,000 bonus caller prize on 02/06/03! this is the 2nd attempt to reach YOU! call 09066362231 ASAP! BOX97N7QP, 150PPM -- Prediction : ['spam']
#
# S.No. 1379: Message : I'm going 4 lunch now wif my family then aft dat i go str 2 orchard lor. -- Prediction : ['ham']
#
# S.No. 1380: Message : I knew it... U slept v late yest? Wake up so late... -- Prediction : ['ham']
#
# S.No. 1381: Message : No i'm not gonna be able to. || too late notice. || i'll be home in a few weeks anyway. || what are the plans -- Prediction : ['ham']
#
# S.No. 1382: Message : Thats cool princess! I will cover your face in hot sticky cum :) -- Prediction : ['ham']
#
# S.No. 1383: Message : Howz pain.it will come down today.do as i said ystrday.ice and medicine. -- Prediction : ['ham']
#
# S.No. 1384: Message : Just normal only here :) -- Prediction : ['ham']
#
# S.No. 1385: Message : Ur HMV Quiz cash-balance is currently £500 - to maximize ur cash-in now send HMV1 to 86688 only 150p/msg -- Prediction : ['spam']
#
# S.No. 1386: Message : Aight, we'll head out in a few -- Prediction : ['ham']
#
# S.No. 1387: Message : I'm aight. Wat's happening on your side. -- Prediction : ['ham']
#
# S.No. 1388: Message : Sorry i cant take your call right now. It so happens that there r 2waxsto do wat you want. She can come and ill get her medical insurance. And she'll be able to deliver and have basic care. I'm currently shopping for the right medical insurance for her. So just give me til friday morning. Thats when i.ll see the major person that can guide me to the right insurance. -- Prediction : ['ham']
#
# S.No. 1389: Message : Will do, you gonna be at blake's all night? I might be able to get out of here a little early -- Prediction : ['ham']
#
# S.No. 1390: Message : Ok thanx... -- Prediction : ['ham']
#
# S.No. 1391: Message : If you still havent collected the dough pls let me know so i can go to the place i sent it to get the control number -- Prediction : ['ham']
#
# S.No. 1392: Message : Hey r ü still online? I've finished the formatting... -- Prediction : ['ham']
